# %%
import osmnx as ox, networkx as nx, matplotlib.cm as cm, pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd
import functools
import community

from scipy import sparse
from scipy.sparse import linalg
import time
from shapely.geometry import Point, LineString, Polygon, MultiPolygon, mapping
from math import sqrt
import pandas as pd
from shapely.ops import cascaded_union
pd.set_option('precision', 10)

# %%
address = '2700 Shattuck Ave, Berkeley, CA'
f = ox.graph_from_address(address, network_type='drive', distance=750, simplify = True)
f = ox.project_graph(f)
fig, ax = ox.plot_graph(f, fig_height=10, node_color='orange', node_size=30, 
                        node_zorder=2, node_edgecolor='k')

# %%
nodes = ox.graph_to_gdfs(f, edges=False)
buffered_nodes = nodes.buffer(15).unary_union
if isinstance(buffered_nodes, Polygon): buffered_nodes = [buffered_nodes]

# %%
buffered_nodes_geoS = gpd.GeoSeries(list(buffered_nodes))
buffered_nodes_df =  pd.concat([buffered_nodes_geoS.rename('geometry'), 
                                 pd.Series(buffered_nodes_geoS.index).rename('code')], axis=1)

buffered_nodes_gdf = gpd.GeoDataFrame(buffered_nodes_df , geometry = buffered_nodes_df.geometry)

# %%
buffered_nodes_gdf['area']= buffered_nodes_gdf['geometry'].area
buffered_nodes_gdf['centroid'] = buffered_nodes_gdf.geometry.centroid

# %%
nodes['cluster'] ='NA'

for row in nodes.itertuples():
    for row_bn in buffered_nodes_gdf.itertuples():
        if (row_bn[buffered_nodes_gdf.columns.get_loc("area")+1] < 706): continue
        elif row[nodes.columns.get_loc("geometry")+1].within(row_bn[buffered_nodes_gdf.columns.get_loc("geometry")+1]): 
            nodes.set_value(row[0], 'cluster', row_bn[buffered_nodes_gdf.columns.get_loc("code")+1])

# %%
merged = buffered_nodes_gdf[buffered_nodes_gdf["area"] > 706]

for row in merged.itertuples():
    
    x, y = row[merged.columns.get_loc("centroid")+1].coords.xy
    merged.set_value(row[0],'x', x[0])
    merged.set_value(row[0], 'y', y[0])
# Out:
# C:\Users\g_filo01\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\g_filo01\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
edges = ox.graph_to_gdfs(f, nodes = False)
edges = edges.rename(columns = {'u':'old_u'})
edges = edges.rename(columns = {'v':'old_v'})

# %%
for row in edges.itertuples():
    
    index_old_u = edges.columns.get_loc("old_u")+1
    index_old_v = edges.columns.get_loc("old_v")+1   
    index_geometry = edges.columns.get_loc("geometry")+1   
    
    line_list = list(row[index_geometry].coords)
        
    u = nodes.loc[row[index_old_u]]["cluster"]
    v = nodes.loc[row[index_old_v]]["cluster"]
   
    if ((u != 'NA') & (v !='NA')):
            line_list[-1] = (merged.loc[v]['x'], merged.loc[v]['y'])
            line_list[0] = (merged.loc[u]['x'], merged.loc[u]['y'])
    elif ((u == 'NA') & (v =='NA')):
            u = row[index_old_u]
            v = row[index_old_v]
    elif (u == 'NA'): 
            u = row[index_old_u]
            line_list[-1] = (merged.loc[v]['x'], merged.loc[v]['y'])
    elif (v == 'NA'): 
            v = row[index_old_v]
            line_list[0] = (merged.loc[u]['x'], merged.loc[u]['y'])
        
    lineGeo = (LineString([coor for coor in line_list])).simplify(1, preserve_topology =True)   
        
    edges.set_value(row[0],"u", u)
    edges.set_value(row[0],"v", v)
    edges.set_value(row[0],"geometry", lineGeo)

# %%
for row in edges.itertuples():
    if (row[0] is in dropped :continue 
    index_key = edges.columns.get_loc("key")+1
    index_type = edges.columns.get_loc("highway")+1
    index_u = edges.columns.get_loc("u")+1
    index_v = edges.columns.get_loc("v")+1
    index_geometry = edges.columns.get_loc("geometry")+1
    
    for rowC in edges.itertuples():
        if row[0] == rowC[0]: continue
        if ((row[index_u] != rowC[index_u] & row[index_u] != rowC[index_v]) | 
            (row[index_u] != rowC[index_v] & row[index_v] != rowC[index_u])): continue
        if row[index_key] != rowC[index_key]: continue
        if ((row[index_type] == 'motorway') != (row[index_type] == 'motorway'): continue
        
        else:
            lineGeometry_A = list(row[index_geometry].coords)
            lineGeometry_B = list(rowC[index_geometry].coords)
            
            if len (lineGeometry_A) == len(lineGeometry_B):
                to_drop = True
                new_line = lineGeometry_A
                for n, i in enumerate(lineGeometry_A):
                    if (n == 0): continue
                    elif (n == len(lineGeometry_A)-1): continue
                    else:
                        AB = LineString([coor for coor in [lineGeometry_A[n], lineGeometry_B[n]]])
                        new_point = AB.centroid            
                        new_line[n] = new_point
                
        lineGeo = LineString([coor for coor in [lineS[0], lineS[1]]])
        edges.set_value(row[0],'geometry', lineGeo)
        edges.set_value(row[0],'oneway', False)   
        if (to_drop == True): 
            edges.drop([rowC[0]])
            dropped.append(rowC[0])

# %%
for row in merged.itertuples():
    index_x = merged.columns.get_loc("x")+1
    index_y = merged.columns.get_loc("y")+1

    index_centroid = merged.columns.get_loc("centroid")+1
    nodes_new.loc[row[0]] = ["NaN", "NaN", "NaN", "NaN", row[index_x],row[index_y], row[index_centroid],'NA']

# %%
nodes_new = nodes_new[nodes_new['cluster'] == "NA"]
nodes_new['osmid'] = nodes_new.index.astype(int)
nodes_new['x'] = nodes_new['x'].astype(float)
nodes_new['y'] = nodes_new['y'].astype(float)
nodes_new.gdf_name = 'new_nodes'

# %%
G = ox.gdfs_to_graph(nodes_new, edges)

# %%
# G = ox.project_graph(G)
fig, ax = ox.plot_graph(G, fig_height=10, node_color='orange', node_size=30, 
                        node_zorder=2, node_edgecolor='k')

# %%
address = '2700 Shattuck Ave, Berkeley, CA'
f = ox.graph_from_address(address, network_type='drive', distance=750)
f = ox.project_graph(f)
fig, ax = ox.plot_graph(f, fig_height=10, node_color='orange', node_size=30, 
                        node_zorder=2, node_edgecolor='k')

# %%
for row in nodes.:
    if (i not in list(nodes_fil.index)): continue
    else:
        cluster = nodes_fil.loc[i]['cluster']
        modify[i] = cluster

# %%
for i in G.edges():
    print(G[i[0]][i[1]])
# Out:
# {0: {'osmid': 22372749, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.418365546772861, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764DD8>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.90966234441541, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764DA0>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 202.63978598714942, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764AC8>}}
# {0: {'osmid': 22372749, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 104.62479995419169, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764D30>}}
# {0: {'osmid': 22372749, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.418365546772876, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764CF8>}}
# {0: {'osmid': 21459592, 'oneway': True, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 200.91917323966769, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764C88>}}
# {0: {'osmid': 22372749, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 104.6247999541917, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764C50>}}
# {0: {'osmid': [415876793, 201989366], 'lanes': ['4', '5'], 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 103.25033848702093, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764C18>}}
# {0: {'osmid': [201989365, 415876797], 'lanes': ['4', '5'], 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.994634407770604, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764E80>}}
# {0: {'osmid': 21459592, 'oneway': True, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 214.42710758118031, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764E48>}}
# {0: {'osmid': 27767099, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.71923056133629, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764E10>}}
# {0: {'osmid': 541063988, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.36053232646998, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764FD0>}}
# {0: {'osmid': 201989363, 'oneway': True, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 182.30947884811889, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764F98>}}
# {0: {'osmid': [415878153, 415878143], 'oneway': True, 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 101.57386420469891, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764F60>}}
# {0: {'osmid': 28436853, 'oneway': True, 'name': 'Fulton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 20.520055494212983, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764D68>}}
# {0: {'osmid': 201989363, 'oneway': True, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 201.36145617947273, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768048>}}
# {0: {'osmid': 541335064, 'oneway': True, 'name': 'Dwight Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 202.4300926735373, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887681D0>}}
# {0: {'osmid': 6329875, 'name': 'Dowling Place', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 9.1172620099825838}}
# {0: {'osmid': 6329875, 'name': 'Dowling Place', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 110.76332167448992, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768198>}}
# {0: {'osmid': [21466380, 416105069], 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 84.098448982007667, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768160>}}
# {0: {'osmid': 209307271, 'oneway': False, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 71.087116511131384}}
# {0: {'osmid': 6329875, 'name': 'Dowling Place', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 110.7633216744899, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768128>}}
# {0: {'osmid': 209307271, 'oneway': False, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 79.569791977844659, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887680F0>}}
# {0: {'osmid': 6331671, 'name': 'Walker Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 90.282228044580876, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768080>}}
# {0: {'osmid': 34811472, 'name': 'Derby Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 145.76963839418238, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768390>}}
# {0: {'osmid': 34811472, 'name': 'Derby Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 72.877866099340253, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768358>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 148.41837656412383, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887682E8>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.13261199501562, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768320>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.60100285604159, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768240>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 200.84343834102242, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887682B0>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 148.41837656412383, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768208>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.08927711530485, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768550>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.0164799795166, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768518>}}
# {0: {'osmid': 32456661, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.09103429769564}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 119.71797484422888, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887684E0>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 200.84343834102242, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768438>}}
# {0: {'osmid': 32456661, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.60881278575555, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768400>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 28.511308888848962}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 59.912941748580536, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887683C8>}}
# {0: {'osmid': [165864168, 415876771], 'oneway': True, 'name': 'Adeline Street', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 128.33197975512792, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768780>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 241.08076864573894, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768748>}}
# {0: {'osmid': 6332538, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 59.912941748580536, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768710>}}
# {0: {'osmid': [517593874, 575429935], 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 74.033669238291822, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887686D8>}}
# {0: {'osmid': 575429935, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.73928638471563, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887686A0>}}
# {0: {'osmid': 515883300, 'name': 'Stuart Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 7.6880117336228384}}
# {0: {'osmid': 202317716, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 104.20244630008904, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768630>}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 96.550452442836885, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887685F8>}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.79279465877777, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887685C0>}}
# {0: {'osmid': [415876793, 201989366], 'lanes': ['4', '5'], 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 103.25033848702093, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768588>}}
# {0: {'osmid': [415876787, 417694687], 'oneway': True, 'name': 'Haste Street', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 200.70965320204004, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887689B0>}}
# {0: {'osmid': 541063988, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.36053232646996, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768978>}}
# {0: {'osmid': 541064916, 'oneway': True, 'name': 'Haste Street', 'highway': 'tertiary', 'maxspeed': '25 mph', 'length': 11.502476618052645}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 88.790313687208425}}
# {0: {'osmid': 6333782, 'name': 'Otis Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 206.66751541547316, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768940>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 96.536976288908775, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768908>}}
# {0: {'osmid': 6333782, 'name': 'Otis Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 206.66751541547316, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887688D0>}}
# {0: {'osmid': [416102059, 417696901], 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 35.124747312131028, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768898>}}
# {0: {'osmid': 417696901, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 96.01997030888387, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768828>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 202.63978598714942, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887687F0>}}
# {0: {'osmid': 25968337, 'name': 'McGee Avenue', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 112.52626777892488, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887687B8>}}
# {0: {'osmid': 25968351, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 200.53425513085179, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768BA8>}}
# {0: {'osmid': 25968351, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 200.60374593018886, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768B70>}}
# {0: {'osmid': 25968351, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 141.558015806778, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768B00>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 102.45502781929177, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768AC8>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.08927711530485, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768A90>}}
# {0: {'osmid': 25968351, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 78.909503890637765, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768A20>}}
# {0: {'osmid': 25968351, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 200.60374593018886, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A887689E8>}}
# {0: {'osmid': [25968331, 32456661], 'name': ['Russell Street', 'Milvia Street'], 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 105.19179313149672, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768D30>}}
# {0: {'osmid': 32456661, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.60881278575556, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768CF8>}}
# {0: {'osmid': 25968351, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 28.653520249091578}}
# {0: {'osmid': 202317699, 'oneway': True, 'name': 'Adeline Street', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 110.69384932288077, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768CC0>}}
# {0: {'osmid': [474057088, 23226442, 474057090], 'oneway': True, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 100.46950683594233, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768C88>}}
# {0: {'osmid': 23226443, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 253.72728767415953, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768C50>}}
# {0: {'osmid': [416111322, 515885395], 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.963902295457885, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768BE0>}}
# {0: {'osmid': 575429935, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.73928638471563, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768F60>}}
# {0: {'osmid': 23226443, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 199.200716463069, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768F28>}}
# {0: {'osmid': 23226443, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 253.72728767415953, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768EF0>}}
# {0: {'osmid': 164659462, 'name': 'Fulton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.816258004063727, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768EB8>}}
# {0: {'osmid': 164659462, 'name': 'Fulton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.504532978167703, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768E80>}}
# {0: {'osmid': 23226443, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 206.9082664715782, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768E10>}}
# {0: {'osmid': 23226443, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 199.200716463069, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768DD8>}}
# {0: {'osmid': 164659450, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.614122295020053, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768DA0>}}
# {0: {'osmid': 164659450, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.100135210860842, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768D68>}}
# {0: {'osmid': 23226443, 'name': 'Oregon Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 6.8498397782728899}}
# {0: {'osmid': [515883296, 574299582], 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 104.43019244963619, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768FD0>}}
# {0: {'osmid': 6342406, 'name': 'Ellis Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.00987154576566, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764F28>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 54.193050304011884, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B0F0>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 92.240710288573993, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B0B8>}}
# {0: {'osmid': 6342406, 'name': 'Ellis Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.91831067112653, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B048>}}
# {0: {'osmid': 6342406, 'name': 'Ellis Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.00987154576569, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B278>}}
# {0: {'osmid': 201989350, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 92.334607423618422, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B240>}}
# {0: {'osmid': 201989350, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 91.933462481426687, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B208>}}
# {0: {'osmid': 6342406, 'name': 'Ellis Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.91831067112653, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B1D0>}}
# {0: {'osmid': 164659475, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 91.873678450978574, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B198>}}
# {0: {'osmid': 164659475, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 86.949683157564337, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B128>}}
# {0: {'osmid': 427003073, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 13.050082928317693}}
# {0: {'osmid': 6342542, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 104.29110376367689, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B470>}}
# {0: {'osmid': 196739917, 'oneway': True, 'name': 'Adeline Street', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 85.965703218706395, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B438>}}
# {0: {'osmid': 25315896, 'name': 'Wheeler Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.427962314738977}}
# {0: {'osmid': 25315896, 'name': 'Wheeler Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.438607285253227}}
# {0: {'osmid': 6342542, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 180.61000273230414, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B400>}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 96.364186831251189}}
# {0: {'osmid': 25968349, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 53.940645778623903, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B3C8>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 92.240710288574007, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B390>}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 96.364186831251189}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.17367256053649, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B320>}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.79279465877777, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B2E8>}}
# {0: {'osmid': 6343678, 'name': 'King Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.17367256053649, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B2B0>}}
# {0: {'osmid': 201989350, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 91.933462481426687, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B4E0>}}
# {0: {'osmid': 6350384, 'name': 'Harper Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.19574277451781, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B4A8>}}
# {0: {'osmid': 164659475, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 93.66651406122628, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B550>}}
# {0: {'osmid': 164659475, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 91.873678450978574, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B518>}}
# {0: {'osmid': 25315896, 'name': 'Wheeler Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.427962314738977}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 94.036164925659762, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B5C0>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 184.69548914108785, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B7B8>}}
# {0: {'osmid': 25315896, 'name': 'Wheeler Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 75.167545687982155, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B780>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 94.25381707520549}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 94.036164925659762, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B748>}}
# {0: {'osmid': 25316471, 'name': 'Fulton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 245.92691679306094, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B710>}}
# {0: {'osmid': 21466380, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 16.695955195653895}}
# {0: {'osmid': 427182574, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 8.5489343406696889}}
# {0: {'osmid': 16260976, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 132.28105816099333, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B6D8>}}
# {0: {'osmid': 16260976, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 132.28105816099333, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B668>}}
# {0: {'osmid': 209307271, 'oneway': False, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 12.751258933502154, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B630>}}
# {0: {'osmid': 209307271, 'oneway': False, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 79.569791977844659, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B5F8>}}
# {0: {'osmid': 25968337, 'name': 'McGee Avenue', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 112.52626777892488, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B9B0>}}
# {0: {'osmid': 25968349, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 53.940645778623896, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B978>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.55118903856899}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 94.677704624076881, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B940>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 170.54875684483855, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B908>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.333149461348285, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B8D0>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.76109541532101, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B860>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 200.66782780051275, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B828>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 170.54875684483855, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B7F0>}}
# {0: {'osmid': 32456661, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.0402045045673}}
# {0: {'osmid': 32456661, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.40128986930765, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BBA8>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 215.99290299079954, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BB70>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 200.66782780051275, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BB38>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 11.466376786614044}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 204.04681704874318, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BB00>}}
# {0: {'osmid': [415878144, 415878156], 'oneway': True, 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 100.81154531853024, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88764EB8>}}
# {0: {'osmid': 24024251, 'name': 'Fulton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.56866601587676}}
# {0: {'osmid': 24024251, 'name': 'Fulton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.74143045019429, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BAC8>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 194.61539392826847, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BA58>}}
# {0: {'osmid': 210456949, 'oneway': False, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 204.04681704874318, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BA20>}}
# {0: {'osmid': 25316538, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.21139098325141, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876B9E8>}}
# {0: {'osmid': 25316538, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.44411196891249, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BD68>}}
# {0: {'osmid': 164659438, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 116.14729715337569, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BD30>}}
# {0: {'osmid': 164659438, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 196.87164219424977, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BCF8>}}
# {0: {'osmid': 164659438, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 6.8590439053631389}}
# {0: {'osmid': 164659438, 'name': 'Carleton Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 46.060155057167179, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BCC0>}}
# {0: {'osmid': 202317716, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 104.04614614361698, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BC50>}}
# {0: {'osmid': 25315661, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 57.52328928123535, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BC18>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 38.036121937637873, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BBE0>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 54.193050304011884, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BF28>}}
# {0: {'osmid': 6350384, 'name': 'Harper Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 203.850758955765, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BEF0>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.734637552542111, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BEB8>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 38.036121937637873, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BE80>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 96.536976288908775, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BE10>}}
# {0: {'osmid': 168627951, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.734637552542111, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BDD8>}}
# {0: {'osmid': [416112025, 201989365], 'lanes': ['4', '5'], 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 206.33617708152215, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BDA0>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 102.45502781929177, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BFD0>}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 28.842565464933433}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 64.953778295039001, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876BF98>}}
# {0: {'osmid': 202317699, 'oneway': True, 'name': 'Adeline Street', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 111.54469858698342, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88768F98>}}
# {0: {'osmid': 6383013, 'name': 'Newbury Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 160.64779314154399, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E198>}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 77.578067880846731, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E160>}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 64.953778295039001, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E128>}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 82.399745419941098, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E0F0>}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 77.578067880846731, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E0B8>}}
# {0: {'osmid': [416111322, 515885395], 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.963902295457899, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E3C8>}}
# {0: {'osmid': [416111321, 518489610, 515885395], 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 160.61693236164521, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E390>}}
# {0: {'osmid': 6401499, 'name': 'Lorina Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 143.07330270353845}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 83.408327806045648}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 82.399745419941084, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E358>}}
# {0: {'osmid': 25315893, 'name': 'Wheeler Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 141.24369666477958}}
# {0: {'osmid': 25968331, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 83.408327806045648}}
# {0: {'osmid': 25316336, 'name': 'Deakin Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 146.48714700948858, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E320>}}
# {0: {'osmid': 164659476, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 94.703183544192129, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E2E8>}}
# {0: {'osmid': 164659476, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.107157912497726, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E240>}}
# {0: {'osmid': 164659477, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 6.7571089906196811}}
# {0: {'osmid': 164659477, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.661099491680176, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E208>}}
# {0: {'osmid': 515883296, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 104.30327606092665, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E1D0>}}
# {0: {'osmid': 6386342, 'name': 'Florence Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 159.78631276739006, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E668>}}
# {0: {'osmid': 164659477, 'name': 'Russell Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.661099491680176, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E630>}}
# {0: {'osmid': 24028181, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 185.00205043995607, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E5F8>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 102.39886092209903, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E5C0>}}
# {0: {'osmid': 26379345, 'name': 'Grant Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.90966234441542, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E588>}}
# {0: {'osmid': 24028181, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 185.00205043995609, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E550>}}
# {0: {'osmid': 24028181, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.15001786604691, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E518>}}
# {0: {'osmid': 201989365, 'lanes': '4', 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 102.51584909169631, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E4A8>}}
# {0: {'osmid': [201989365, 415876797], 'lanes': ['4', '5'], 'name': 'Martin Luther King Junior Way', 'highway': 'tertiary', 'maxspeed': '25 mph', 'oneway': False, 'length': 99.994634407770604, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E470>}}
# {0: {'osmid': 24028181, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.15001786604691, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E438>}}
# {0: {'osmid': 24028181, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 215.16983965060072, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E400>}}
# {0: {'osmid': 27767099, 'name': 'Milvia Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.71923056133629, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E898>}}
# {0: {'osmid': 24028181, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 11.536119957226212}}
# {0: {'osmid': [28436848, 24028181], 'name': ['Blake Street', 'Fulton Street'], 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 267.22275011958362, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E860>}}
# {0: {'osmid': 88446824, 'oneway': True, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 101.14316123028499, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E828>}}
# {0: {'osmid': 24024250, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.89629199654678, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E7F0>}}
# {0: {'osmid': [24024250, 24024251], 'name': ['Blake Street', 'Fulton Street'], 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 295.8312182161597, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E7B8>}}
# {0: {'osmid': 25316837, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.66853932608069, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E780>}}
# {0: {'osmid': 25316837, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 74.490480611338583, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E710>}}
# {0: {'osmid': 25316538, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 82.986927038349904}}
# {0: {'osmid': 24024250, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 87.691733657531529, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E6D8>}}
# {0: {'osmid': 24024250, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 201.89629199654678, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E6A0>}}
# {0: {'osmid': 25316538, 'name': 'Dana Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.90956365496633, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876EB00>}}
# {0: {'osmid': 6404484, 'name': 'Chilton Way', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 102.10666521161588}}
# {0: {'osmid': 24024250, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 83.258746281335817, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876EAC8>}}
# {0: {'osmid': 24024250, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 87.691733657531529, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876EA90>}}
# {0: {'osmid': 24024250, 'name': 'Blake Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 6.7424210572549788}}
# {0: {'osmid': 34811472, 'name': 'Derby Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 202.28769656125334, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876EA58>}}
# {0: {'osmid': 34811472, 'name': 'Derby Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 199.70075641504977, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876EA20>}}
# {0: {'osmid': 164659447, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.055967352096886, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E9E8>}}
# {0: {'osmid': 164659447, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.423464956736908, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E9B0>}}
# {0: {'osmid': 164659449, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 89.275354137013736}}
# {0: {'osmid': 6388344, 'name': 'Howe Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 161.98012953283293, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E940>}}
# {0: {'osmid': 164659449, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 52.604583783817148, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8876E908>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 35.695722460793455}, 1: {'osmid': 516589462, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 35.695722460793455}}
# ...
# {0: {'osmid': 164659510, 'oneway': True, 'highway': 'residential', 'maxspeed': '25 mph', 'length': 7.8916126769685864, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B5F8>}}
# {0: {'osmid': 164659473, 'name': 'Parker Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 197.57491361244598, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B5C0>}}
# {0: {'osmid': 164659510, 'oneway': True, 'highway': 'residential', 'maxspeed': '25 mph', 'length': 7.0820700079152923, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B588>}}
# {0: {'osmid': 25316837, 'name': 'Ellsworth Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 95.66853932608069, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B550>}}
# {0: {'osmid': 164659510, 'oneway': True, 'highway': 'residential', 'maxspeed': '25 mph', 'length': 7.7446414584566696, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B4A8>}}
# {0: {'osmid': 198549475, 'name': 'Emerson Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 175.81418809279435, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B470>}}
# {0: {'osmid': 198549475, 'name': 'Emerson Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 180.76640464033881, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B438>}}
# {0: {'osmid': [421385008, 417696932], 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 83.89809757969654, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B828>}}
# {0: {'osmid': 421385008, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 81.022724298804562, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B7F0>}}
# {0: {'osmid': 6372435, 'name': 'Tremont Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 78.580242455544408, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B7B8>}}
# {0: {'osmid': 10723756, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 78.47524145329686, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B780>}}
# {0: {'osmid': 10723756, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 181.45690429408563, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B6D8>}}
# {0: {'osmid': 10723756, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 88.374313734956672, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B6A0>}}
# {0: {'osmid': 10723756, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 78.47524145329686, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B668>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 80.265198943649168}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 90.657229764305299, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BA20>}}
# {0: {'osmid': 10723756, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 168.46122634175566, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B9E8>}}
# {0: {'osmid': 10723756, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 88.374313734956672, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B9B0>}}
# {0: {'osmid': 195604802, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 89.769167011005877, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B978>}}
# {0: {'osmid': 421385008, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 79.366440213241191, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B8D0>}}
# {0: {'osmid': 6372435, 'name': 'Tremont Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.55023859741928}}
# {0: {'osmid': 6342542, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 175.43674025755385, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B898>}}
# {0: {'osmid': 6342542, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 104.29110376367689, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877B860>}}
# {0: {'osmid': 6372435, 'name': 'Tremont Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.909827995938969, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BC50>}}
# {0: {'osmid': 6342542, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 180.61000273230414, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BC18>}}
# {0: {'osmid': 6342542, 'name': 'Essex Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 175.43674025755385, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BBE0>}}
# {0: {'osmid': 421385008, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 81.022724298804562, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BBA8>}}
# {0: {'osmid': 421385008, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 81.200947807783393, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BB70>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 90.657229764305285, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BAC8>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 78.609390621475981, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BA90>}}
# {0: {'osmid': [416111321, 518489610, 515885395], 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 160.61693236164518, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BA58>}}
# {0: {'osmid': [421385008, 417696932], 'lanes': ['2', '3'], 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 83.898097579696525, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BE48>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 171.15813533441226, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BE10>}}
# {0: {'osmid': 6372435, 'name': 'Tremont Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 78.580242455544408, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BDD8>}}
# {0: {'osmid': 6372435, 'name': 'Tremont Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.909827995938969, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BDA0>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 184.69548914108785, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BCF8>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 171.15813533441226, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BCC0>}}
# {0: {'osmid': 421385008, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 81.200947807783393, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BC88>}}
# {0: {'osmid': 421385008, 'lanes': '2', 'name': 'Shattuck Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'oneway': False, 'length': 79.366440213241191, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BFD0>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 80.265198943649168}}
# {0: {'osmid': 25315896, 'name': 'Wheeler Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 84.799463300767258, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BF98>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 96.630435999250665, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BEF0>}}
# {0: {'osmid': 6372435, 'name': 'Tremont Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 80.55023859741928}}
# {0: {'osmid': 198549475, 'name': 'Emerson Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 180.76640464033881, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877BEB8>}}
# {0: {'osmid': 198549475, 'name': 'Emerson Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 65.338387425098816, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A88778DD8>}}
# {0: {'osmid': 25315883, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 7.9598703464764942}}
# {0: {'osmid': 25315883, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 148.1705959269627, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E080>}}
# {0: {'osmid': 202317717, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 25.91815739251475, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E048>}}
# {0: {'osmid': 427182574, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 8.5489343406696889}}
# {0: {'osmid': 202317717, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 86.659121919774364, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E240>}}
# {0: {'osmid': 202317717, 'oneway': True, 'name': 'Telegraph Avenue', 'highway': 'secondary', 'maxspeed': '25 mph', 'length': 16.691366132788588}}
# {0: {'osmid': 427003074, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 8.5920499727767083}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 65.357790754102808, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E208>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 90.177567335412505}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 94.25381707520549}}
# {0: {'osmid': 6379723, 'name': 'Deakin Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 138.94870920265481, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E1D0>}}
# {0: {'osmid': 6379723, 'name': 'Deakin Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.80378798259196, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E128>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 19.587091597958139}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 65.357790754102808, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E0F0>}}
# {0: {'osmid': 6383231, 'oneway': True, 'name': 'Halcyon Court', 'highway': 'residential', 'maxspeed': '25 mph', 'length': 80.109888368690093, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E0B8>}}
# {0: {'osmid': 6379723, 'name': 'Deakin Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 100.80378798259196, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E438>}}
# {0: {'osmid': 6379723, 'name': 'Deakin Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.2009881136368, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E400>}}
# {0: {'osmid': 25315883, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 148.17059592696268, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E3C8>}}
# {0: {'osmid': 25315883, 'name': 'Woolsey Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 168.51771232298441, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E390>}}
# {0: {'osmid': 6379723, 'name': 'Deakin Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 101.2009881136368, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E2E8>}}
# {0: {'osmid': 6397312, 'oneway': False, 'name': '66th Street', 'highway': 'residential', 'length': 109.90534364516206, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E2B0>}}
# {0: {'osmid': 6397312, 'oneway': False, 'name': '66th Street', 'highway': 'residential', 'length': 123.10525643970885, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E278>}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 54.573259686713612}, 1: {'osmid': 516589461, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 54.573259686713612}}
# {0: {'osmid': 202317700, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 54.573259686713612}, 1: {'osmid': 516589461, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 54.573259686713612}}
# {0: {'osmid': 416102057, 'oneway': False, 'lanes': '4', 'ref': 'CA 13', 'name': 'Ashby Avenue', 'highway': 'primary', 'maxspeed': '25 mph', 'length': 41.890230494690925, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000025A8877E668>}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 19.587091597958139}}
# {0: {'osmid': 6344484, 'name': 'Prince Street', 'highway': 'residential', 'maxspeed': '25 mph', 'oneway': False, 'length': 90.177567335412505}}

# %%
G = ox.gdfs_to_graph(nodes, edges)
    t = G.nodes()
    pos = {}

    for l, item in enumerate(t): pos[item] = (t[l]['x'],t[l]['y'], t[item]['nodeID'])

    Ng = nx.Graph() #Empty graph
    Ng = Ng.to_undirected()
    Ng.add_nodes_from(pos.keys()) #Add nodes preserving coordinates

    for i, item in enumerate(Ng.nodes()):
        Ng.node[item]['x']=pos[item][0]
        Ng.node[item]['y']=pos[item][1]
        Ng.node[item]['nodeID']=pos[item][2]

    for i, item in enumerate(G.edges()):
        Ng.add_edge(item[0], item[1])
        Ng[item[0]][item[1]]['length']=G[item[0]][item[1]][0]['length']
        Ng[item[0]][item[1]]['streetID']=G[item[0]][item[1]][0]['streetID']
# Out:
# 0       978.3286614526
# 1       705.7234103712
# 2       705.7234103712
# 3       705.7234103712
# 4       705.7234103712
# 5      1051.0807942793
# 6       705.7234103712
# 7       705.7234103712
# 8      1597.7516599473
# 9       705.7234103712
# 10     2015.6090307559
# 11      705.7234103712
# 12      705.7234103712
# 13     1156.7040296244
# 14      705.7234103712
# 15      705.7234103712
# 16      705.7234103712
# 17      705.7234103712
# 18      705.7234103712
# 19      705.7234103712
# 20      705.7234103712
# 21      705.7234103712
# 22     1075.3509488184
# 23      705.7234103712
# 24      705.7234103712
# 25      705.7234103712
# 26      705.7234103712
# 27     1574.9214933777
# 28      705.7234103712
# 29     1248.7463545033
#             ...
# 128     905.3361377536
# 129     705.7234103712
# 130     705.7234103712
# 131     705.7234103712
# 132     705.7234103712
# 133    1193.2775414594
# 134    1042.4725909049
# 135     705.7234103712
# 136    1035.5115234009
# 137     705.7234103712
# 138     705.7234103712
# 139     906.5048489492
# 140    1244.5648755060
# 141     705.7234103712
# 142    1368.9208331176
# 143     705.7234103712
# 144    1152.8981019528
# 145     705.7234103712
# 146     705.7234103712
# 147     705.7234103712
# 148    1043.4125349254
# 149     705.7234103712
# 150     705.7234103712
# 151     914.2375653216
# 152     705.7234103712
# 153     705.7234103712
# 154    1204.6611495727
# 155    1181.9115616921
# 156    1404.1280586049
# 157     705.7234103712
# Length: 158, dtype: float64

# %% [markdown]
# # Functions

# %%
#try reading street network

#streets = gpd.read_file('C:/Users/gabri/Google Drive Academic/GIS/OS_Roads_Working/OS_roads_final.shp')
streets = gpd.read_file('C:/Users/gabri/sciebo/GIS Data/Street_Network/in_use/Boston_clipped_cleaned.shp')

# %%
# streets = streets.to_crs(epsg=27700) #UK
streets = streets.to_crs(epsg=2806) #Boston, MA

# %%
# if ('OBJECTID' in df.columns):

streets['from'] = "NaN"
streets['to'] = "NaN"

streets = streets[['CLASS','STREET_NAM','geometry', 'from', 'to']]
# df = streets[(streets.duplicated(subset='OBJECTID', keep=False))==True]

# %%
#removing Z coordinates and storing from/to coordinates and assigning 

for index, row in streets.iterrows():
    line = []
    line2 = []
    coord = list(row['geometry'].coords)
    from_node = coord[0][0:2]
    to_node = coord[-1][0:2]
    for i in range(0,len(coord)):
        point = coord[i][0:2]
        line.append(point)

    t = LineString([coor for coor in line])
    streets.set_value(index,'geometry', t)
    streets.set_value(index, 'from', from_node)
    streets.set_value(index, 'to', to_node)
    #setting ObjectID equal to index for avoiding ambiguosity (this is useful for edges)

# %%
streets.head()
# Out:
#    CLASS         STREET_NAM  \
# 0      5       ATHOL STREET
# 1      5  LITCHFIELD STREET
# 2      5     EVERETT STREET
# 3      5      WALNUT STREET
# 4      5      MYRICK STREET
#
#                                             geometry  \
# 0  LINESTRING (447666.5001382427 151131.711515581...
# 1  LINESTRING (447123.6569959233 151039.425289589...
# 2  LINESTRING (447500.2996802317 151134.078397393...
# 3  LINESTRING (453340.9429937318 151020.118995716...
# 4  LINESTRING (448023.0267885827 151137.325709729...
#
#                                        from  \
# 0   (447666.5001382427, 151131.71151558135)
# 1   (447123.6569959233, 151039.42528958918)
# 2   (447500.2996802317, 151134.07839739308)
# 3    (453340.9429937318, 151020.1189957167)
# 4  (448023.02678858273, 151137.32570972946)
#
#                                         to
# 0  (447695.2985308499, 151220.14891192896)
# 1  (447152.86840961257, 151121.6688060242)
# 2  (447518.13484683307, 151173.3807869006)
# 3  (453354.5999694744, 150969.40344899317)
# 4  (447986.2441860455, 151198.58021859944)

# %%
#removing edges represented only by nodes
streets = streets.loc[streets['from'] != streets['to']]
streets.reset_index(inplace=True, drop=True)
streets['OBJECTID'] = streets.index.values.astype(int) 
streets.head()
# Out:
#    CLASS         STREET_NAM  \
# 0      5       ATHOL STREET
# 1      5  LITCHFIELD STREET
# 2      5     EVERETT STREET
# 3      5      WALNUT STREET
# 4      5      MYRICK STREET
#
#                                             geometry  \
# 0  LINESTRING (447666.5001382427 151131.711515581...
# 1  LINESTRING (447123.6569959233 151039.425289589...
# 2  LINESTRING (447500.2996802317 151134.078397393...
# 3  LINESTRING (453340.9429937318 151020.118995716...
# 4  LINESTRING (448023.0267885827 151137.325709729...
#
#                                        from  \
# 0   (447666.5001382427, 151131.71151558135)
# 1   (447123.6569959233, 151039.42528958918)
# 2   (447500.2996802317, 151134.07839739308)
# 3    (453340.9429937318, 151020.1189957167)
# 4  (448023.02678858273, 151137.32570972946)
#
#                                         to  OBJECTID
# 0  (447695.2985308499, 151220.14891192896)         0
# 1  (447152.86840961257, 151121.6688060242)         1
# 2  (447518.13484683307, 151173.3807869006)         2
# 3  (453354.5999694744, 150969.40344899317)         3
# 4  (447986.2441860455, 151198.58021859944)         4

# %%
#extracting nodes and greating a geodataframe
unique_nodes_tmp = list(streets['to'].unique()) + list(streets['from'].unique())
unique_nodes = list(set(unique_nodes_tmp))

crs = {'init': '2806'}

# %%
nodes_data = pd.DataFrame.from_records(unique_nodes, columns=['x', 'y']).astype('float')
geometry = [Point(xy) for xy in zip(nodes_data.x, nodes_data.y)]
nodes_geo = gpd.GeoDataFrame(nodes_data, crs=crs, geometry=geometry)

# %%
nodes_tmp = nodes_geo.reset_index()
nodes_tmp['coordinates']=list(zip(nodes_tmp.x, nodes_tmp.y))

# %%
result_tmp = pd.merge(streets, nodes_tmp[['index', 'coordinates']], how='left', left_on="from", right_on="coordinates")
result_tmp = result_tmp.drop(result_tmp[['coordinates']],axis=1)
result_tmp = result_tmp.rename(columns = {'index':'u'})

# %%
result = pd.merge(result_tmp, nodes_tmp[['index', 'coordinates']], how='left', left_on="to", right_on="coordinates")
result = result.drop(result[['coordinates', 'from', 'to']],axis=1)
result = result.rename(columns = {'index':'v'})
result['key']=0 #for OSMNx
result['distance'] = gpd.GeoSeries(result['geometry'].length)

# %%
nodes_geo.crs
# Out:
# {'init': '2806'}

# %%
nodes_geo.head()
# Out:
#                    x                  y  \
# 0  454376.0808189199  147736.0375299623
# 1  455164.7128765391  143262.4066902359
# 2  456338.9251517847  155897.2979695652
# 3  450661.3033107797  152945.4141076953
# 4  450724.3698959947  157042.6592945328
#
#                                       geometry
# 0  POINT (454376.0808189199 147736.0375299623)
# 1  POINT (455164.7128765391 143262.4066902359)
# 2  POINT (456338.9251517847 155897.2979695652)
# 3  POINT (450661.3033107797 152945.4141076953)
# 4  POINT (450724.3698959947 157042.6592945328)

# %%
m[0]
# Out:
# 15669

# %%
nodes_geo.loc[[17604, 21, 7756, 13792, 1625], 'cluster']
# Out:
# 17604     17
# 21        17
# 7756     903
# 13792    903
# 1625     903
# Name: cluster, dtype: int64

# %%
l = [10,1,12,13,14,15]

# %%
t = [10,12,13,14,15]

# %%
s = [1]

# %%
n = [x for x in l if (x not in t) & (x not in s)]
n
# Out:
# []

# %%
t = [list(s)].remove(0)
t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-521-c561ac8d5cac> in <module>()
# ----> 1 t = [list(s)].remove(0)
#       2 t
#
# ValueError: list.remove(x): x not in list

# %%
s =[0,1,2]

# %%
s.remove(0)
s
# Out:
# [1, 2]

# %%
tmp
# Out:
# [8215]

# %%
processed = []
sindex = nodes_geo.sindex
clusters = {}
key = 1
nodes_geo['cluster'] = 0

for row in nodes_geo.itertuples():
    
    if (row[0] in processed): continue
        
    g = row[3] #geometry
    fil = g.buffer(15)
        
    tmp_match = list(sindex.intersection(fil.bounds))
    match_index = [x for x in tmp_match if x not in processed]
    processed.append(row[0])

    if (len(match_index)<2): continue #no adjacent nodes----------
    near_index = match_index[:]
    near_index.remove(row[0])
    
    near = nodes_geo.iloc[near_index]
    for n in near.itertuples():
                        
            g = n[3] #geometry
            fil = g.buffer(10)
            tmpp = list(sindex.intersection(fil.bounds))
            
            second_near = [x for x in tmp if (x not in processed) & (x not in match_index)]
            processed.extend(second_near)           
            match_index.extend(second_near)
            
            
#             for i in second_near:
#                 if  (i in match_index): continue
#                 elif (i in processed): continue
#                 else: match_index.append(i)
    
    processed.extend(match_index)
    nodes_geo.loc[match_index, 'cluster']=key
    clusters[key] = match_index
    key = key+1

# %%
nodes_geo.loc[[14924, 1, 263, 5553, 16033, 13175, 3966]]
# Out:
#                        x                  y  \
# 14924  455130.5735762698  143258.3152442727
# 1      455164.7128765391  143262.4066902359
# 263    455166.6804121623  143262.6424907026
# 5553   455189.5973327883  143265.3889819069
# 16033  455195.9433649664  143266.1495254797
# 13175  455202.9470598020  143266.9888868800
# 3966   455162.9467381680  143267.4461936107
#
#                                           geometry  cluster
# 14924  POINT (455130.5735762698 143258.3152442727)        2
# 1      POINT (455164.7128765391 143262.4066902359)        2
# 263    POINT (455166.6804121623 143262.6424907026)        2
# 5553   POINT (455189.5973327883 143265.3889819069)        2
# 16033  POINT (455195.9433649664 143266.1495254797)        2
# 13175     POINT (455202.947059802 143266.98888688)        2
# 3966    POINT (455162.946738168 143267.4461936107)        2

# %%
nodes_geo.crs = {'init': 'epsg:2806', 'no_defs': True}
nodes_geo.to_file('Outputs/new_nodes.shp', driver='ESRI Shapefile')

# %%
from shapely import geometry

# %%
nodes_geo = nodes_geo[~nodes_geo.index.isin(n)]

# %%
clusters
# Out:
# {0: [1, 263, 3966],
#  1: [96, 8454],
#  2: [110, 111],
#  3: [198, 10602, 5430],
#  4: [296, 255],
#  5: [274, 271],
#  6: [279, 18004],
#  7: [5681, 368],
#  8: [3962, 378],
#  9: [7463, 7462, 406],
#  10: [7204, 419],
#  11: [459, 463],
#  12: [10858, 493],
#  13: [6415, 523, 527],
#  14: [7995, 575],
#  15: [600, 3164],
#  16: [674, 672],
#  17: [1467, 772],
#  18: [2301, 854],
#  19: [926, 2264, 2263],
#  20: [8605, 989],
#  21: [1030, 9510],
#  22: [1070, 15051, 15056],
#  23: [10008, 1098],
#  24: [1114, 12639],
#  25: [8449, 1165],
#  26: [3619, 1210],
#  27: [14039, 1357],
#  28: [18433, 1386],
#  29: [1426, 8478],
#  30: [1529, 1526],
#  31: [1573, 4593],
#  32: [1607, 5658],
#  33: [1617, 14129],
#  34: [5947, 1685],
#  35: [7030, 1687],
#  36: [9459, 1705],
#  37: [1811, 14525],
#  38: [17368, 1849],
#  39: [1912, 4542],
#  40: [1923, 1920],
#  41: [2011, 17271],
#  42: [2016, 2015],
#  43: [4306, 4307, 2019],
#  44: [2037, 6655],
#  45: [2057, 2054],
#  46: [2150, 2147],
#  47: [2152, 2725],
#  48: [2358, 9955],
#  49: [2408, 2924],
#  50: [2416, 7686],
#  51: [5827, 2421],
#  52: [12068, 2454],
#  53: [2488, 2487],
#  54: [2563, 2565],
#  55: [2749, 2750],
#  56: [2765, 12854],
#  57: [11188, 18598, 2769],
#  58: [2789, 2790],
#  59: [2800, 2797],
#  60: [2871, 11026],
#  61: [3068, 17907],
#  62: [3131, 3132],
#  63: [15240, 3146],
#  64: [14728, 3186, 13853],
#  65: [3197, 3192],
#  66: [3292, 3286],
#  67: [3343, 3346],
#  68: [3355, 17652],
#  69: [14118, 3535],
#  70: [3582, 3583],
#  71: [3674, 3677],
#  72: [3694, 3696],
#  73: [18447, 3762],
#  74: [3785, 3782],
#  75: [15979, 3795],
#  76: [3842, 18797],
#  77: [263, 3966, 1],
#  78: [4000, 4003],
#  79: [4082, 10862],
#  80: [4197, 4198],
#  81: [16683, 4242],
#  82: [4294, 14701],
#  83: [7162, 4329],
#  84: [8310, 4410],
#  85: [4418, 4419],
#  86: [4446, 4448],
#  87: [4451, 5105],
#  88: [11507, 4463],
#  89: [4483, 4484],
#  90: [13505, 4650],
#  91: [4718, 4717],
#  92: [4734, 4740],
#  93: [4819, 14840],
#  94: [4871, 4872],
#  95: [4924, 4923],
#  96: [5643, 4964],
#  97: [5156, 12548],
#  98: [6012, 5184],
#  99: [5226, 5222],
#  100: [8515, 5341, 17818],
#  101: [5530, 15377],
#  102: [10641, 5540],
#  103: [5626, 5628],
#  104: [5656, 5659],
#  105: [5820, 5817],
#  106: [5909, 5907],
#  107: [19001, 5939],
#  108: [13998, 5962],
#  109: [5963, 5967],
#  110: [6881, 5975],
#  111: [5980, 5981],
#  112: [6301, 6300],
#  113: [6425, 6428],
#  114: [9668, 6552],
#  115: [6649, 13698],
#  116: [6692, 16110],
#  117: [6807, 6802],
#  118: [6818, 7483],
#  119: [6822, 6824],
#  120: [7029, 16055],
#  121: [7073, 11866],
#  122: [7081, 7082],
#  123: [7097, 7095],
#  124: [7231, 7235],
#  125: [7234, 7233],
#  126: [7265, 7267],
#  127: [11243, 7287],
#  128: [7357, 7355],
#  129: [7414, 7412],
#  130: [8723, 7436],
#  131: [7755, 9772],
#  132: [7815, 12088],
#  133: [7831, 18532],
#  134: [7832, 7835],
#  135: [7920, 8609],
#  136: [7935, 7934],
#  137: [11311, 7978],
#  138: [7988, 7987],
#  139: [7998, 13280],
#  140: [15860, 8041, 17136],
#  141: [9878, 8049],
#  142: [8052, 13336],
#  143: [8813, 8101],
#  144: [8195, 8191],
#  145: [8247, 16666],
#  146: [8291, 10322],
#  147: [15611, 8399],
#  148: [10273, 8561],
#  149: [8577, 9240],
#  150: [8578, 8579],
#  151: [8638, 8632],
#  152: [8689, 8690],
#  153: [8878, 8877],
#  154: [8924, 16109],
#  155: [9059, 9056],
#  156: [9161, 13102],
#  157: [16990, 16988, 9207],
#  158: [9224, 9221],
#  159: [16883, 9362],
#  160: [12605, 9438],
#  161: [9509, 14439],
#  162: [10327, 9628, 18690],
#  163: [9836, 10468],
#  164: [9882, 9883],
#  165: [9930, 9927],
#  166: [10032, 10033],
#  167: [10066, 10068],
#  168: [10109, 10108],
#  169: [10112, 10111],
#  170: [13687, 10163],
#  171: [10279, 10991],
#  172: [11287, 10519],
#  173: [19083, 13723, 10539],
#  174: [17248, 10540],
#  175: [10635, 10640],
#  176: [17516, 10685],
#  177: [10687, 10688],
#  178: [10994, 10995],
#  179: [11180, 11181],
#  180: [11194, 11195],
#  181: [17039, 11200],
#  182: [11316, 12289],
#  183: [11339, 11347],
#  184: [11492, 11493],
#  185: [11511, 11516],
#  186: [11695, 17062],
#  187: [11752, 11744],
#  188: [12188, 16301],
#  189: [12210, 12215],
#  190: [12262, 12973, 12972],
#  191: [12267, 12264],
#  192: [17833, 12337],
#  193: [18786, 12458],
#  194: [16718, 12628],
#  195: [12650, 13799],
#  196: [12762, 14035],
#  197: [17128, 12782],
#  198: [12890, 12891],
#  199: [13028, 13032],
#  200: [13207, 13206],
#  201: [13232, 13233],
#  202: [17658, 13250],
#  203: [13345, 17091],
#  204: [15614, 13497],
#  205: [17848, 13545],
#  206: [13598, 18293],
#  207: [13615, 16378],
#  208: [17333, 13737],
#  209: [13748, 13749],
#  210: [13770, 13771],
#  211: [13956, 13955],
#  212: [13959, 13958],
#  213: [14034, 14037],
#  214: [14130, 14128],
#  215: [15901, 14366],
#  216: [14433, 14435],
#  217: [14531, 17955],
#  218: [14546, 14543],
#  219: [14754, 14752],
#  220: [14791, 14788],
#  221: [15236, 15239],
#  222: [15275, 15277],
#  223: [15352, 15351],
#  224: [15468, 17914],
#  225: [15591, 15588],
#  226: [15596, 15603],
#  227: [18194, 15630],
#  228: [15747, 15748],
#  229: [15819, 15815],
#  230: [16609, 15948],
#  231: [18022, 15964],
#  232: [16014, 16017],
#  233: [16248, 16383],
#  234: [16448, 16447],
#  235: [16628, 16627],
#  236: [16745, 16747],
#  237: [16754, 17964],
#  238: [16929, 17635],
#  239: [17088, 17085],
#  240: [15860, 17136, 8041],
#  241: [17164, 17165],
#  242: [17228, 17227],
#  243: [17427, 17428],
#  244: [18124, 17432],
#  245: [17818, 8515, 5341],
#  246: [17947, 17948],
#  247: [17953, 17956],
#  248: [18099, 18098],
#  249: [18228, 18224],
#  250: [18274, 18275],
#  251: [18755, 18760],
#  252: [18794, 18792],
#  253: [18895, 18891]}

# %%
new = result.copy()
to_redraw = []

for k, n in clusters.items():
    small = nodes_geo.iloc[n]
    coord = list(small.geometry)
    
    if (len(coord)<3):
        l = geometry.LineString([[p.x, p.y] for p in coord])
    else: 
        l = geometry.Polygon([[p.x, p.y] for p in coord])
        
    nodes_geo.loc[nodes_geo.index.values.max()+1] = (l.centroid.coords[0][0], #x
                                                    l.centroid.coords[0][1], #y
                                                    l.centroid)  #geometry
    
    to_redraw.extend(list(new.loc[new['u'].isin(n) | new['v'].isin(n)].index.values))
    new.loc[new['u'].isin(n), 'u']= nodes_geo.index.values.max()
    new.loc[new['v'].isin(n), 'v']= nodes_geo.index.values.max() 
        
    #removing old_nodes

# %%
new.loc[0].geometry.coords[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-380-00a0a3006105> in <module>()
# ----> 1 new.loc[0].geometry.coords[3]
#
# C:\Users\gabri\Anaconda3\lib\site-packages\shapely\coords.py in __getitem__(self, key)
#      97         if isinstance(key, int):
#      98             if key + m < 0 or key >= m:
# ---> 99                 raise IndexError("index out of range")
#     100             if key < 0:
#     101                 i = m + key
#
# IndexError: index out of range

# %%
new = new.loc[new['u'] != new['v']]
check = [x for x in to_redraw if x in list(new.index.values)]

# %%
for i in new.loc[check].itertuples():
    new['geometry'].loc[i[0]] = LineString([(nodes_geo['x'].loc[i[5]], nodes_geo['y'].loc[i[5]]),
                                              (nodes_geo['x'].loc[i[6]], nodes_geo['y'].loc[i[6]])])
# Out:
# C:\Users\gabri\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
nodes_geo.loc[i[6]]
# Out:
# x                                           450746.3896
# y                                            150128.957
# geometry    POINT (450746.3896290048 150128.9569718847)
# Name: 11795, dtype: object

# %%
new.to_file('Outputs/new.shp', driver='ESRI Shapefile')
